# %%
from nba_api.stats.endpoints import leaguedashteamstats
import requests
import json
import pandas as pd
from IPython.display import display

# %%
response = leaguedashteamstats.LeagueDashTeamStats(
    team_id_nullable='0',
    league_id_nullable='00',
    season= '2023-24',
    last_n_games='10',
    season_type_all_star='Regular Season',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})


df = response.get_data_frames()[0]

# %%
display(df)
# Out:
#        TEAM_ID               TEAM_NAME  GP  W   L  W_PCT     MIN  FGM  FGA  \
# 0   1610612737           Atlanta Hawks  10  5   5    0.5  479.75  439  943
# 1   1610612738          Boston Celtics  10  9   1    0.9  480.00  452  874
# 2   1610612751           Brooklyn Nets  10  2   8    0.2  480.00  374  873
# 3   1610612766       Charlotte Hornets  10  5   5    0.5  480.00  392  854
# 4   1610612741           Chicago Bulls  10  5   5    0.5  490.00  431  911
# 5   1610612739     Cleveland Cavaliers  10  7   3    0.7  480.00  428  839
# 6   1610612742        Dallas Mavericks  10  7   3    0.7  480.00  448  888
# 7   1610612743          Denver Nuggets  10  6   4    0.6  480.00  430  906
# 8   1610612765         Detroit Pistons  10  3   7    0.3  485.00  421  894
# 9   1610612744   Golden State Warriors  10  8   2    0.8  480.00  458  954
# 10  1610612745         Houston Rockets  10  2   8    0.2  480.00  389  915
# ...

# %%
df.columns
# Out:
# Index(['TEAM_ID', 'TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA',
#        'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB',
#        'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS',
#        'PLUS_MINUS', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
#        'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
#        'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
#        'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
#        'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK'],
#       dtype='object')

# %%
df1 = df.drop(columns=['MIN', 'PF', 'PFD', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
       'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
       'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
       'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
       'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK'])

# %%
df1.columns
# Out:
# Index(['TEAM_ID', 'TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'TOV', 'STL', 'BLK', 'BLKA', 'PTS', 'PLUS_MINUS'],
#       dtype='object')

# %%
display(df1)
# Out:
#        TEAM_ID               TEAM_NAME  GP  W   L  W_PCT  FGM  FGA  FG_PCT  \
# 0   1610612737           Atlanta Hawks  10  5   5    0.5  439  943   0.466
# 1   1610612738          Boston Celtics  10  9   1    0.9  452  874   0.517
# 2   1610612751           Brooklyn Nets  10  2   8    0.2  374  873   0.428
# 3   1610612766       Charlotte Hornets  10  5   5    0.5  392  854   0.459
# 4   1610612741           Chicago Bulls  10  5   5    0.5  431  911   0.473
# 5   1610612739     Cleveland Cavaliers  10  7   3    0.7  428  839   0.510
# 6   1610612742        Dallas Mavericks  10  7   3    0.7  448  888   0.505
# 7   1610612743          Denver Nuggets  10  6   4    0.6  430  906   0.475
# 8   1610612765         Detroit Pistons  10  3   7    0.3  421  894   0.471
# 9   1610612744   Golden State Warriors  10  8   2    0.8  458  954   0.480
# 10  1610612745         Houston Rockets  10  2   8    0.2  389  915   0.425
# ...

# %%
display(df1.sort_values('W_PCT', ascending=False))
# Out:
#        TEAM_ID               TEAM_NAME  GP  W   L  W_PCT  FGM  FGA  FG_PCT  \
# 1   1610612738          Boston Celtics  10  9   1    0.9  452  874   0.517
# 15  1610612748              Miami Heat  10  8   2    0.8  413  864   0.478
# 9   1610612744   Golden State Warriors  10  8   2    0.8  458  954   0.480
# 20  1610612760   Oklahoma City Thunder  10  8   2    0.8  464  914   0.508
# 17  1610612750  Minnesota Timberwolves  10  7   3    0.7  421  885   0.476
# 5   1610612739     Cleveland Cavaliers  10  7   3    0.7  428  839   0.510
# 6   1610612742        Dallas Mavericks  10  7   3    0.7  448  888   0.505
# 21  1610612753           Orlando Magic  10  7   3    0.7  419  830   0.505
# 13  1610612747      Los Angeles Lakers  10  7   3    0.7  451  888   0.508
# 18  1610612740    New Orleans Pelicans  10  7   3    0.7  432  889   0.486
# 23  1610612756            Phoenix Suns  10  6   4    0.6  441  878   0.502
# ...

# %%
home_response = leaguedashteamstats.LeagueDashTeamStats(
    team_id_nullable='0',
    league_id_nullable='00',
    season= '2023-24',
    season_type_all_star='Regular Season',
    location_nullable='Home',
    headers={'Accept': 'application/json, text/plain, */*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'en-US,en;q=0.9',
'Connection': 'keep-alive',
'Host': 'stats.nba.com',
'Origin': 'https://www.nba.com',
'Referer': 'https://www.nba.com/',
'sec-ch-ua': '"Google Chrome";v="87", "\"Not;A\\Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?1',
'Sec-Fetch-Dest': 'empty',
'Sec-Fetch-Mode': 'cors',
'Sec-Fetch-Site': 'same-site',
'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Mobile Safari/537.36',
'x-nba-stats-origin': 'stats',
'x-nba-stats-token': 'true'})


home_df = home_response.get_data_frames()[0]

# %%
home_df1 = home_df.drop(columns=['MIN', 'PF', 'PFD', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK',
       'FGM_RANK', 'FGA_RANK', 'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK',
       'FG3_PCT_RANK', 'FTM_RANK', 'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK',
       'DREB_RANK', 'REB_RANK', 'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK',
       'BLKA_RANK', 'PF_RANK', 'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK'])

# %%
display(home_df1.sort_values('W_PCT', ascending=False))
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT   FGM   FGA  FG_PCT  \
# 1   1610612738          Boston Celtics  30  27   3  0.900  1324  2701   0.490
# 7   1610612743          Denver Nuggets  27  22   5  0.815  1214  2384   0.509
# 20  1610612760   Oklahoma City Thunder  30  24   6  0.800  1367  2680   0.510
# 17  1610612750  Minnesota Timberwolves  27  21   6  0.778  1094  2242   0.488
# 16  1610612749         Milwaukee Bucks  31  24   7  0.774  1371  2779   0.493
# 12  1610612746             LA Clippers  27  20   7  0.741  1155  2325   0.497
# 21  1610612753           Orlando Magic  27  19   8  0.704  1131  2328   0.486
# 13  1610612747      Los Angeles Lakers  29  20   9  0.690  1261  2522   0.500
# 19  1610612752         New York Knicks  30  20  10  0.667  1241  2679   0.463
# 10  1610612745         Houston Rockets  30  20  10  0.667  1256  2697   0.466
# 5   1610612739     Cleveland Cavaliers  30  20  10  0.667  1305  2674   0.488
# ...
